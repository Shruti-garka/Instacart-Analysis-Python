# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing df using os library

# %%
# Assigning path
path = r'C:\Users\Shruthi\Desktop\CF_Tasks\21-06-2023_Instacart_Basket_Analysis'

# %%
# Importing df_prods
df_prods =  pd.read_csv(os.path.join(path, '2. Data', 'Prepared data', 'products_checked.csv'), index_col = False)

# %%
# Importing pickle file
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '2. Data', 'Prepared data', 'orders_products_combined.pkl'))

# %%
# Checking dimensions
df_ords_prods_combined.shape
# Out:
# (32434489, 12)

# %% [markdown]
# # Merging df

# %%
# Checking dimensions of df_ords_prods_combined
df_ords_prods_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           0   2539329        1    prior             1                   2
# 2           0   2539329        1    prior             1                   2
# 3           0   2539329        1    prior             1                   2
# 4           0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN         196                  1
# 1                  8                    NaN       14084                  2
# 2                  8                    NaN       12427                  3
# 3                  8                    NaN       26088                  4
# 4                  8                    NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# ...

# %%
# Checking dimensions of df_prods
df_prods.shape
# Out:
# (49672, 6)

# %%
# Checking dimensions of df_prods
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Drop existing merge column 
df_ords_prods_combined = df_ords_prods_combined.drop(columns = ['_merge'])

# %%
# Merging the dataset
df_merged = df_ords_prods_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
# Checking
df_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN         196                  1
# 1                  7                   15.0         196                  1
# 2                 12                   21.0         196                  1
# 3                  7                   29.0         196                  1
# 4                 15                   28.0         196                  1
#
# ...

# %%
# Drop unneccesary column
df_merged = df_merged.drop(columns = ['Unnamed: 0_x'])

# %%
# Checking
df_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN         196                  1
# 1                  7                   15.0         196                  1
# 2                 12                   21.0         196                  1
# 3                  7                   29.0         196                  1
# 4                 15                   28.0         196                  1
#
#    reordered  Unnamed: 0_y product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# # Confirming the results using merge flag

# %%
df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#checkinging dimensions
df_merged.shape
# Out:
# (32404859, 16)

# %% [markdown]
# # Export the file

# %%
#Exoprting df_merged as pickle file 
df_merged.to_pickle(os.path.join(path, '2. Data','Prepared data', 'orders_products_merged.pkl'))
